# %% [markdown]
# # Rock Paper Scissors
# ![image.png](attachment:image.png)

# %%
import random

# %%
user_action = input("Enter a choice ('rock', 'paper', 'scissors'): ")
possible_actions = ["rock","paper","scissors"]
computer_action = random.choice(possible_actions)

print(f"You chose {user_action}, computer chose {computer_action}.\n")


user_points =     possible_actions.index(user_action)
computer_points = possible_actions.index(computer_action)

if user_points == computer_points:
    print(f"Both players selected {user_action}. It's a tie!")
else:

    win = (computer_points+1)%3
    if user_points == win:
        print("You won!")
    else:
        print("You lost!")
# Out:
# You chose scissors, computer chose rock.
#
# You lost!
